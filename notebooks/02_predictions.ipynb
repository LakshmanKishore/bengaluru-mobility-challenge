# %%
import cv2
import sys
sys.path.append("../")
from scripts.yolo_predictions import YOLO_Pred

# %%
yolo = YOLO_Pred('../hackathon-info/colabmodels/best.onnx','../data.yaml')

# %%
img = cv2.imread('../hackathon-info/data_images/train/frame_100.jpg')

cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# predictions
img_pred = yolo.predictions(img)

# %%
cv2.imshow('prediction image',img_pred)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Real Time Object Detection

# %%
cap = cv2.VideoCapture('../hackathon-info/processed_videos/reduced_one_fps_full.mp4')


while True:
    ret, frame = cap.read()
    if ret == False:
        print('unable to read video')
        break

    pred_image = yolo.predictions(frame)

    cv2.imshow('YOLO',pred_image)
    if cv2.waitKey(1) == 27:
        break

cv2.destroyAllWindows()
cap.release()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 10
#       7     print('unable to read video')
#       8     break
# ---> 10 pred_image = yolo.predictions(frame)
#      12 cv2.imshow('YOLO',pred_image)
#      13 if cv2.waitKey(1) == 27:
#
# File d:\Github\Data_Science\hackathon\bengaluru-mobility-challenge\notebooks\..\scripts\yolo_predictions.py:80, in YOLO_Pred.predictions(self, image)
#      77 confidences_np = np.array(confidences).tolist()
#      79 # NMS
# ---> 80 index = cv2.dnn.NMSBoxes(boxes_np,confidences_np,0.25,0.45).flatten()
#      83 # Draw the Bounding
#      84 for ind in index:
#      85     # extract bounding box
#
# AttributeError: 'tuple' object has no attribute 'flatten'

# %%
BASE_PATH = "../hackathon-info"

# %%
cap = cv2.VideoCapture('../hackathon-info/processed_videos/reduced_one_fps_full.mp4')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use appropriate codec based on desired output format
out = cv2.VideoWriter(f'{BASE_PATH}/processed_videos/yolo_model_predictions_best.mp4', fourcc, 1, (int(cap.get(3)), int(cap.get(4))))


while True:
    ret, frame = cap.read()
    if not ret:
        print('unable to read video')
        break

    pred_image = yolo.predictions(frame)

    # cv2.imshow('YOLO',pred_image)
    out.write(pred_image)
    if cv2.waitKey(1) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()
# Out:
# boxes_np: [[1181, -2, 101, 101], [1186, 4, 86, 111], [1185, 0, 85, 119], [1199, 29, 56, 116], [1197, 28, 53, 115], [1200, 33, 48, 116], [1248, 76, 48, 127], [1247, 70, 51, 133], [1247, 82, 45, 125], [1246, 81, 48, 127], [1180, -3, 107, 103], [1184, 5, 91, 110], [1182, 5, 94, 113], [1199, 32, 57, 112], [1197, 31, 55, 112], [1200, 35, 50, 114], [1247, 76, 51, 126], [1248, 68, 52, 139], [1247, 79, 48, 130], [1247, 80, 48, 130], [1177, -2, 111, 101], [1187, 3, 84, 113], [1184, 2, 87, 115], [1201, 29, 53, 116], [1200, 29, 51, 114], [1200, 34, 48, 114], [1246, 76, 51, 127], [1247, 66, 53, 139], [1244, 80, 51, 128], [1244, 80, 51, 128], [1182, 4, 98, 99], [1189, 3, 81, 119], [1183, 8, 99, 108], [1201, 37, 57, 113], [1246, 69, 51, 138], [1250, 60, 53, 138], [1245, 74, 52, 129], [1183, 4, 99, 101], [1188, 3, 84, 119], [1185, 5, 92, 104], [1199, 29, 55, 123], [1244, 66, 53, 141], [1246, 73, 52, 132], [1179, 7, 103, 97], [1189, 3, 82, 125], [1185, 7, 93, 109], [1200, 29, 58, 124], [1248, 67, 50
# ...

# %%
yolob = YOLO_Pred('../hackathon-info/colabmodels/best100.onnx','../data.yaml')

# %%
cap = cv2.VideoCapture('../hackathon-info/processed_videos/reduced_one_fps_full.mp4')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use appropriate codec based on desired output format
out = cv2.VideoWriter(f'{BASE_PATH}/processed_videos/yolo_model_predictions_best100.mp4', fourcc, 1, (int(cap.get(3)), int(cap.get(4))))


while True:
    ret, frame = cap.read()
    if not ret:
        print('unable to read video')
        break

    pred_image = yolob.predictions(frame)

    # cv2.imshow('YOLO',pred_image)
    out.write(pred_image)
    if cv2.waitKey(1) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()
# Out:
# unable to read video

# %%
cap = cv2.VideoCapture('../hackathon-info/processed_videos/sbi_bnk_jn_first_30_seconds.mp4')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use appropriate codec based on desired output format
out = cv2.VideoWriter(f'{BASE_PATH}/processed_videos/sbi_bnk_jn_yolo_model_predictions_best100.mp4', fourcc, 1, (int(cap.get(3)), int(cap.get(4))))


while True:
    ret, frame = cap.read()
    if not ret:
        print('unable to read video')
        break

    pred_image = yolob.predictions(frame)

    # cv2.imshow('YOLO',pred_image)
    out.write(pred_image)
    if cv2.waitKey(1) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()
# Out:
# unable to read video

# %%
cap = cv2.VideoCapture('../hackathon-info/processed_videos/18th_Crs_BsStp_JN_FIX_2_first_30_seconds_with_5_fps.mp4')
fourcc = cv2.VideoWriter_fourcc(*'mp4v')  # Use appropriate codec based on desired output format
out = cv2.VideoWriter(f'{BASE_PATH}/processed_videos/18th_Crs_BsStp_jn_30_seconds_with_5_fps_yolo_model_predictions_best100.mp4', fourcc, 1, (int(cap.get(3)), int(cap.get(4))))


while True:
    ret, frame = cap.read()
    if not ret:
        print('unable to read video')
        break

    pred_image = yolob.predictions(frame)

    # cv2.imshow('YOLO',pred_image)
    out.write(pred_image)
    if cv2.waitKey(1) == 27:
        break

cv2.destroyAllWindows()
cap.release()
out.release()
# Out:
# unable to read video
